# %% [markdown]
# ## GR5291 ALS
# ### cy2475 Chenghao Yu

# %%
# import ALS and Linear Regression models
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.ml.regression import DecisionTreeRegressor
from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import IndexToString, StringIndexer, VectorIndexer
from pyspark.ml.classification import RandomForestClassifier
from pyspark.sql import Row
from pyspark.sql import SparkSession

# %%
from pyspark import SparkContext
from pyspark import SQLContext
sc = SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

# %%
import pandas as pd
import time

# %%
df_train = pd.read_csv("training.csv")
df_test = pd.read_csv("testing.csv")

# %%
df_train['set'] = [1]*df_train.shape[0]
df_test['set'] = [0]*df_test.shape[0]

# %%
df = pd.concat([df_train, df_test])

# %%
df[0:5]
# Out:
#                                            msno  \
# 0  qXWBbfsZ6923Dq7OvwMP2rtVE3phQqlEKcLp2I5wofw=
# 1  Qja9LnwXWgTjFG5G1iMm/1J5Be6jhD/LUikBU9e9bWg=
# 2  6fGAUf1BJeTefYr5PUdmJVQ80DWsKr/3JRIf2w9MGAk=
# 3  dY4MN8EfoumZIs/0+ugiv/qGkNWIWdnWLIrFpjFYNTw=
# 4  kktfViwY41gERgWGXWDnVPl/oNF5fLNigX11zfhVOl0=
#
#                                         song_id source_system_tab  \
# 0  JTMsJNPcL2ambkp1Z/MeBEnFEzZEOKetdLPrJxHf7v8=          discover
# 1  zuyzUP11fbgoVp6IMfWK378GDToe59ZlK5gkf+7aKdg=        my library
# 2  TuknjyN6Uqqrm49GZYBfTY4I2fjJwr11nVb18xlgmEE=        my library
# 3  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=        my library
# 4  wcw0/6Vl8mOPpS0WUysfaKaOv8eAXim4/LAQfyFhgZU=        my library
#
#     source_screen_name     source_type  target        artist_name genre_ids  \
# 0  Local playlist more   local-library       0            BIGBANG       465
# 1           My library            song       0        家家 (JiaJia)       458
# 2  Local playlist more  local-playlist       1     周杰倫 (Jay Chou)       465
# 3  Local playlist more  local-playlist       1  周湯豪 (NICKTHEREAL)       458
# 4  Local playlist more  local-playlist       1               南拳媽媽       465
#
#    language  song_length  bd  city  gender  registered_via  \
# 0      31.0       220212   0     1     NaN               4
# 1       3.0       249835  42     6    male               9
# 2       3.0       231444  23    13  female               9
# 3       3.0       219324   0     1     NaN               7
# 4       3.0       253074  22     9  female               3
#
#    registration_init_time  expiration_date  set
# 0                20161231         20170103    1
# 1                20060324         20180103    1
# 2                20090815         20180818    1
# 3                20160620         20170919    1
# 4                20150818         20171217    1

# %%
df = df.drop(['source_system_tab','source_screen_name','source_type','artist_name',
              'genre_ids','language','song_length','bd','city','gender','registered_via',
              'registration_init_time','expiration_date'], axis=1)

# %%
df[0:5]
# Out:
#                                            msno  \
# 0  qXWBbfsZ6923Dq7OvwMP2rtVE3phQqlEKcLp2I5wofw=
# 1  Qja9LnwXWgTjFG5G1iMm/1J5Be6jhD/LUikBU9e9bWg=
# 2  6fGAUf1BJeTefYr5PUdmJVQ80DWsKr/3JRIf2w9MGAk=
# 3  dY4MN8EfoumZIs/0+ugiv/qGkNWIWdnWLIrFpjFYNTw=
# 4  kktfViwY41gERgWGXWDnVPl/oNF5fLNigX11zfhVOl0=
#
#                                         song_id  target  set
# 0  JTMsJNPcL2ambkp1Z/MeBEnFEzZEOKetdLPrJxHf7v8=       0    1
# 1  zuyzUP11fbgoVp6IMfWK378GDToe59ZlK5gkf+7aKdg=       0    1
# 2  TuknjyN6Uqqrm49GZYBfTY4I2fjJwr11nVb18xlgmEE=       1    1
# 3  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=       1    1
# 4  wcw0/6Vl8mOPpS0WUysfaKaOv8eAXim4/LAQfyFhgZU=       1    1

# %%
df.msno = pd.Categorical(df.msno)
df['msno_int'] = df.msno.cat.codes
df.song_id = pd.Categorical(df.song_id)
df['song_id_int'] = df.song_id.cat.codes

# %%
df[0:5]
# Out:
#                                            msno  \
# 0  qXWBbfsZ6923Dq7OvwMP2rtVE3phQqlEKcLp2I5wofw=
# 1  Qja9LnwXWgTjFG5G1iMm/1J5Be6jhD/LUikBU9e9bWg=
# 2  6fGAUf1BJeTefYr5PUdmJVQ80DWsKr/3JRIf2w9MGAk=
# 3  dY4MN8EfoumZIs/0+ugiv/qGkNWIWdnWLIrFpjFYNTw=
# 4  kktfViwY41gERgWGXWDnVPl/oNF5fLNigX11zfhVOl0=
#
#                                         song_id  target  set  msno_int  \
# 0  JTMsJNPcL2ambkp1Z/MeBEnFEzZEOKetdLPrJxHf7v8=       0    1     26260
# 1  zuyzUP11fbgoVp6IMfWK378GDToe59ZlK5gkf+7aKdg=       0    1     13695
# 2  TuknjyN6Uqqrm49GZYBfTY4I2fjJwr11nVb18xlgmEE=       1    1      4058
# 3  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=       1    1     20009
# 4  wcw0/6Vl8mOPpS0WUysfaKaOv8eAXim4/LAQfyFhgZU=       1    1     23431
#
#    song_id_int
# 0       118863
# 1       352221
# 2       175975
# 3       306854
# 4       334292

# %%
df_id_pair = df.drop(['target','set'], axis=1)

# %%
df_id_pair.to_csv('strid_intid.csv', index=False)

# %%
df_test_dic = df.loc[df['set']==0]
df_test_dic.to_csv("testing_dic.csv", index=False)

# %%
df = df.drop(['msno','song_id'], axis=1)

# %%
df[0:5]
# Out:
#    target  set  msno_int  song_id_int
# 0       0    1     26260       118863
# 1       0    1     13695       352221
# 2       1    1      4058       175975
# 3       1    1     20009       306854
# 4       1    1     23431       334292

# %%
df.to_csv('ALS.csv', header=False, index=False)

# %%
df_train = df.loc[df['set']==1]
df_test = df.loc[df['set']==0]

# %%
df_train = df_train.drop(['set'],axis=1)
df_test = df_test.drop(['set'],axis=1)

# %%
df_train.to_csv('ALStrain.csv', header = False)
df_test.to_csv('ALStest.csv', header = False)

# %%
# Build a SparkSession; SparkSession provides a single point of entry to interact with underlying Spark functionality
spark = SparkSession\
    .builder\
    .appName("ALSExample")\
    .getOrCreate()

# %%
# Load data as RDD, then transform it to DataFrame format
lines = spark.read.text("ALStrain.csv").rdd
parts = lines.map(lambda row: row.value.split(","))
ratingsRDD = parts.map(lambda p: Row(userId=int(p[2]), songId=int(p[3]),
                                     rating=float(p[1])))
training = spark.createDataFrame(ratingsRDD)
# Split data to training part and test part
#(training, test) = ratings.randomSplit([0.8, 0.2])

# %%
lines = spark.read.text("ALStest.csv").rdd
parts = lines.map(lambda row: row.value.split(","))
ratingsRDD = parts.map(lambda p: Row(userId=int(p[2]), songId=int(p[3]),
                                     rating=float(p[1])))
test = spark.createDataFrame(ratingsRDD)

# %%
# Build the recommendation model using ALS on the training data
# Note we set cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics
als = ALS(maxIter=5, regParam=0.01, userCol="userId", itemCol="songId", ratingCol="rating",
          coldStartStrategy="drop")
model = als.fit(training)

# %%
# Make predictions using the model we just built; Evaluate the model by computing the RMSE on the test data
predictions = model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Root-mean-square error = 0.48113769113975074

# %%
# Generate top 5 movie recommendations for each user
userRecs = model.recommendForAllUsers(10)
userRecs.show()
# Out:
# +------+--------------------+
# |userId|     recommendations|
# +------+--------------------+
# |   148|[[307609, 2.41548...|
# |   463|[[129164, 1.92623...|
# |   471|[[232751, 3.01539...|
# |   496|[[217014, 3.86646...|
# |   833|[[36054, 2.373713...|
# |  1088|[[35059, 2.376929...|
# |  1238|[[232751, 3.17090...|
# |  1580|[[261633, 1.28104...|
# |  1591|[[220835, 2.32352...|
# |  1645|[[166735, 1.39530...|
# |  1829|[[296436, 1.99897...|
# |  1959|[[0, 0.0], [10, 0...|
# |  2122|[[262770, 1.02939...|
# |  2142|[[266513, 3.44459...|
# |  2366|[[91479, 1.260464...|
# |  2659|[[296436, 2.77124...|
# |  2866|[[210452, 0.69766...|
# |  3175|[[338000, 1.98941...|
# |  3749|[[275000, 2.97553...|
# |  3794|[[46443, 2.314936...|
# +------+--------------------+
# only showing top 20 rows

# %%
rlt = userRecs.toPandas()

# %%
rlt.to_csv("result.csv")

# %%
RLT = pd.DataFrame(index=range(rlt.shape[0]),columns=range(11))
RLT.columns = ['ID','R1','R2','R3','R4','R5','R6','R7','R8','R9','R10']

# %%
RLT.ID = rlt.userId
RLT
# Out:
#           ID   R1   R2   R3   R4   R5   R6   R7   R8   R9  R10
# 0        148  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1        463  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2        471  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3        496  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4        833  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5       1088  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6       1238  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 7       1580  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 8       1591  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9       1645  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10      1829  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 11      1959  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 12      2122  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 13      2142  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 14      2366  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 15      2659  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 16      2866  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 17      3175  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 18      3749  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 19      3794  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20      3918  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 21      3997  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 22      4101  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 23      4519  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 24      4818  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 25      4900  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 26      4935  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 27      5156  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 28      5300  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 29      5803  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 30356  25873  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30357  26431  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30358  26527  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30359  26638  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30360  26639  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30361  26694  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30362  27248  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30363  27415  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30364  27788  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30365  27842  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30366  27890  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30367  28131  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30368  28184  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30369  28270  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30370  28293  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30371  28802  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30372  28838  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30373  28890  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30374  28904  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30375  28935  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30376  29162  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30377  29508  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30378  29510  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30379  29639  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30380  29757  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30381  29854  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30382  30200  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30383  30314  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30384  30611  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 30385  30625  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [30386 rows x 11 columns]

# %%
for u in range(rlt.shape[0]):
    for r in range(10):
        RLT.iloc[u,r+1] = rlt.recommendations[u][r][0]
    if u%5000 == 0:
        print(u)
        print('-----')
# Out:
# 0
# -----
# 5000
# -----
# 10000
# -----
# 15000
# -----
# 20000
# -----
# 25000
# -----
# 30000
# -----

# %%
RLT[0:5]
# Out:
#     ID      R1      R2      R3      R4      R5      R6      R7      R8  \
# 0  148  325552  267525  210615  104988  177195  317184  121058  177310
# 1  463  182618  252179  271615  307661  203582   66325    7234  249962
# 2  471  292900   16097  268536  149367   62198   65864  313669  121058
# 3  496   33506   64728  155720   95672  207528   89433  277054  168440
# 4  833   34786  142402  313669  220080  267525   95672   16097   24404
#
#        R9     R10
# 0  204064   31291
# 1  179953  346459
# 2   23984  284220
# 3  273325  196620
# 4  123008  122083

# %%
RLT.to_csv("result_intID.csv", index = False)

# %%
user_id_dic = df_id_pair.drop(['song_id','song_id_int'], axis=1)

# %%
song_id_dic = df_id_pair.drop(['msno','msno_int'], axis=1)

# %%
song_id_dic[0:10]
# Out:
#                                         song_id  song_id_int
# 0  JTMsJNPcL2ambkp1Z/MeBEnFEzZEOKetdLPrJxHf7v8=       118863
# 1  zuyzUP11fbgoVp6IMfWK378GDToe59ZlK5gkf+7aKdg=       352221
# 2  TuknjyN6Uqqrm49GZYBfTY4I2fjJwr11nVb18xlgmEE=       175975
# 3  reXuGcEWDDCnL0K3Th//3DFG4S1ACSpJMzA+CFipo1g=       306854
# 4  wcw0/6Vl8mOPpS0WUysfaKaOv8eAXim4/LAQfyFhgZU=       334292
# 5  i/9mpmgGKK+l3dF0Nczmz5XAzWQplXVVXZKUypdG96g=       254132
# 6  rGQta84AYQvw7EfOxt2eioFMBtTJwH5566r1upAMfU8=       304774
# 7  BAgK0kbiNXGoX0QZzMQSWKizd60+5pjv7SJwRUVRLGk=        73040
# 8  0rKJxDhI03y0+iAVzugYyrpbRHEGjYIDno8T15FM2fo=        15915
# 9  RxxelttQ4TmwwuKb0Cksss9z+9PtyBhG3AK+UoQ7r1c=       165328

# %%
song_id_dic2 = song_id_dic.drop_duplicates()

# %%
user_id_dic2 = user_id_dic.drop_duplicates()

# %%
RLT2 = RLT.copy()

# %%
for u in range(RLT.shape[0]):
    RLT2.iloc[u,0] =  user_id_dic2.loc[user_id_dic2.msno_int==RLT.iloc[u,0]].iloc[0,0]
    if u%5000 == 0:
        print(u)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000

# %%
for u in range(RLT.shape[0]):
    for r in range(10):
        RLT2.iloc[u,r+1] =  song_id_dic2.loc[song_id_dic2.song_id_int==RLT.iloc[u,r+1]].iloc[0,0]
    if u%1000 == 0:
        print(u)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000

# %%
RLT2.to_csv("result_oriID.csv", index = False)

# %%
rlt = pd.read_csv('result_oriID.csv')
dic_rlt = rlt.set_index('ID')
dic_rlt[1:5]
# Out:
#                                                                                         R1  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  V4N/g5U0zScEMDOG3s5TPNQJakxjvWYEy6cdz3ZJBL4=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  p621zOKRZYOkKMkQSYtqpmHP5pquwYXznsoCXULZwsU=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  4++g8du/wzUMEgh1VDI7cO9/UBY3Lb0bkssKJEoET8M=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  4CPsbLnLGbx9AqD/zgLjW1TVkoLMWeLaEeD0JFsqSDI=
#
#                                                                                         R2  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  hdr1w+xO2EmEyYaS/Fw7fysAN3fFegNGWbw6OqNKJ0c=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  0tRDQkhnFxvCvQ3X5sqZzBUZ/LsmZP0gEEUCwqnNZhM=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  9eK08t6s420mylV0ZdAOOCNwWS3fPJKRHIAskF3/kRI=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  NmVv+idRPSgEbcRX/Xa74wzyt9yQqTBeWKCCqVauTvk=
#
#                                                                                         R3  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  lE/JwBjz0xQEWh3Z3VVIs62PqU2aKrptkIZnyFi4BL4=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  kfIo/ICrUHy16+6OSioD7s/tcMNUeAitoIoHs2PECDI=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  QCt0GMS98rF3az6+2tB0YkZdHlr25BH6M/RQAfEvDv4=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  stIfIRARkGfkMLplfC+QCc7YWOqau4T+A7pdmRsd4gQ=
#
#                                                                                         R4  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  rnX8FljjbCJaWynXAo+VyyycE67imloDdZMeylgB50k=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  P1g8PLKzJWacSmRTr2yFF3Fvyab35r2NzPW/0TVe+lw=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  FI/3scaISrLiKqHi99Ug6+iReqQCq4unWgp35gzjtxU=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  bubGTMT3XeT7iWr7iSDnsQqBLpTfvw4R0MT6S8J+9JI=
#
#                                                                                         R5  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  YwJQzIskIUiDSi5OKygFZH/lCvbFIjjtANycZRqfD/U=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  9Auxo08gyygZVQpSknPKIwcNUmewTdZsMTDfLFgQU+k=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  ZeGdxhwPvGs/2C+Z1LG5bBaIfxy0RYhSLNegGNOoWQA=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  kSmKBbsz9aGcYQHBdo/Y1VUwgwrSF/BydcRwTSFksoA=
#
#                                                                                         R6  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  9wnwXv+niMjMtmZyK9ayUdXT1AkuYxojjnf409NyAZw=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  9rM1nc3EnClzYjVTOVaX5E9CfhjCS8ZWj6JRIsFQyPk=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  E931ZzopKXiqz2L2iV+rZ7HVHlwKA3ibPv1Yxbph6Mc=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  FI/3scaISrLiKqHi99Ug6+iReqQCq4unWgp35gzjtxU=
#
#                                                                                         R7  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  /GmBpmhc/8IGjwByeq+O2Kwv11OFfi1PGOs0ZvUJlZ0=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  stIfIRARkGfkMLplfC+QCc7YWOqau4T+A7pdmRsd4gQ=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  mEtCsRukkbHJEd/8pPcWiBmd9E98hpvnQouAven7UWc=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  0tRDQkhnFxvCvQ3X5sqZzBUZ/LsmZP0gEEUCwqnNZhM=
#
#                                                                                         R8  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  hE6aKyhjTdMRw1xIXlDLnZ+EOH0I2YkBcsE4V+wcmAA=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  Jta/oPni6IVILd9492koJ4/9USeCJQeqAISoF4Jf1Gc=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  SVsb0PnY5j7ufX5Dow7ODrbESsAmnPEJtdwq88Hv1wY=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  2OHybmTM1UyiDDE1NlIzavupurXNV7ERV3fKARnGgYU=
#
#                                                                                         R9  \
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  Ucj+8u6eHIYFrKnGIIqDCNfGdEVXPeOsUO671MHNZX4=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  2JEnFftsK5BP5+e1tm+0y1QQzZ5pxUa18SoHwDU63TA=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  lYJzKGHrOBy2En3yIv99/IEvB5dbt7BEe8uAg6fSYQ0=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  KDvJlHjpb7SdNZL8z80bGaYA4GVdfY8pMHfgZI6gokY=
#
#                                                                                        R10
# ID
# /1/GPKvOx2lWLskxHQM+mDKxBFv7XEMPP3TOHaZzHWI=  yrEoWmOyTbHBRz8PXPbg/r8XQEldmiPRcMGDFrwtcyI=
# /27S3WYkO3xYembOe/CpR4LJh6GUdoPbfbvMrhHZfn4=  nYZ4+/1e/QeJzI0an0UL3Tfum+f4jRY1prvqB6anb2E=
# /5Xu7yJZF20khZSpwsqs03K9zmiYqlB9FCtK2QtLdrY=  XeIZEHaojvTt7J0/nQrL5843tFL7Gb5Arur+IOzsbBQ=
# /qAla7c1s0x8MzaHjGDKCza0rHSqa7Y+/zcaWQMBpC4=  K3L1EpapSxiBAwDLMIV5jV+mH9dffNVUoWXNXwgF3O0=
